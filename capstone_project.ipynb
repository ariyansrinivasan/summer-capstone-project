# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv('insurance.csv')
(data.columns)
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
x=data.iloc[:,[0,2,5]].values
y=data.iloc[:,[6,1,4]].values
x
y
# Out:
# array([[16884.924, 'female', 'yes'],
#        [1725.5523, 'male', 'no'],
#        [4449.462, 'male', 'no'],
#        ...,
#        [1629.8335, 'female', 'no'],
#        [2007.945, 'female', 'no'],
#        [29141.3603, 'female', 'yes']], dtype=object)

# %%
le=LabelEncoder()
x[:,2]=le.fit_transform(x[:,2])
print(x[:,2])
# Out:
# [3 2 2 ... 2 3 1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
# [[53 26.6 1]
#  [53 21.4 3]
#  [18 37.29 2]
#  ...
#  [51 34.96 0]
#  [40 22.22 2]
#  [57 27.94 2]]
# [[19 35.53 1]
#  [57 31.54 1]
#  [51 37.0 3]
#  [49 36.63 2]
#  [21 22.3 3]
#  [31 34.39 1]
#  [49 37.51 2]
#  [56 28.595 0]
#  [27 26.03 0]
#  [37 26.4 2]
#  [60 24.53 2]
#  [54 46.7 3]
#  [39 32.34 2]
#  [42 29.0 3]
#  [18 34.43 2]
#  [48 30.2 3]
#  [33 22.705 1]
#  [35 27.7 3]
#  [59 36.52 2]
#  [62 33.2 3]
#  [52 33.25 0]
#  [30 39.05 2]
#  [46 27.74 1]
#  [50 26.6 3]
#  [18 30.115 0]
#  [41 28.405 1]
#  [43 27.36 0]
#  [48 33.33 2]
#  [33 32.9 3]
#  [30 25.46 0]
#  [56 35.8 3]
#  [34 27.0 3]
#  [53 22.61 0]
#  [19 31.92 1]
#  [48 25.85 2]
#  [53 24.32 1]
#  [30 35.3 3]
#  [21 25.7 3]
#  [58 39.05 2]
#  [45 30.495 1]
#  [28 33.0 2]
#  [58 34.39 1]
#  [50 27.83 2]
#  [59 37.1 3]
#  [31 23.6 3]
#  [60 28.595 0]
#  [20 35.31 2]
#  [28 31.68 2]
#  [51 18.05 1]
#  [57 28.785 0]
#  [61 31.57 2]
#  [55 29.7 3]
#  [24 23.655 1]
#  [45 25.7 3]
#  [18 27.36 0]
#  [32 44.22 2]
# ...

# %%
regressor=RandomForestRegressor(criterion="mse")
regressor.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-b3645e181b76> in <module>()
#       1 regressor=RandomForestRegressor(criterion="mse")
# ----> 2 regressor.fit(x,y)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     322
#     323         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
# --> 324             y = np.ascontiguousarray(y, dtype=DOUBLE)
#     325
#     326         if expanded_class_weight is not None:
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py in ascontiguousarray(a, dtype)
#     177
#     178     """
# --> 179     return array(a, dtype, copy=False, order='C', ndmin=1)
#     180
#     181
#
# ValueError: could not convert string to float: 'yes'

# %%
 clf = RandomForestRegressor(random_state=0)

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([ 3111.414626  , 14243.2240936 , 10168.2741242 , 12778.3446929 ,
#         2566.3623395 , 31519.3958295 , 10735.0005889 , 12021.7075231 ,
#         3619.0495785 , 15715.286124  , 13493.9581929 , 14385.2504686 ,
#         6818.7077029 ,  8897.3676259 ,  2490.430375  ,  9668.7944501 ,
#        17168.3032037 ,  7688.7986189 , 31855.6512981 , 16063.1670629 ,
#        10877.5272625 , 29458.8592597 , 11036.6318022 , 10157.9754174 ,
#        10389.35722309,  7433.8050688 , 14902.5503458 , 17131.7120031 ,
#         9908.4251836 ,  5225.624039  , 11567.3495321 , 11684.6557146 ,
#        20827.112397  , 23681.8203328 , 21437.5985825 , 11223.672336  ,
#        33818.7057076 , 13366.708069  , 13969.4969466 , 30521.5503422 ,
#         5709.616635  , 12590.2136202 , 18409.5790956 , 22522.4529996 ,
#         7615.7344218 , 24579.4179851 , 19645.520016  , 26153.442058  ,
#         9752.924094  , 15685.4425825 , 16494.2393329 , 13040.1345889 ,
# ...

# %%
a=(input("enter bmi"))
b=(input("enter children"))
c=int(input("enter region"))
d=(input("enter age"))
# Out:
# enter bmi27.9
# enter children3
# enter region2
# enter age45

# %%
t1=([[a,b,c,d]])
pt1=regressor.predict(t1)
pt1
# Out:
# array([15693.595366])

# %%
plt.scatter(x_test[0], y_train,  color='yellow')
plt.scatter(y_test[6], y_pred,  color='blue')
plt.xticks(())
plt.yticks(())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-edce290fec04> in <module>()
# ----> 1 plt.scatter(x_test[0], y_train,  color='yellow')
#       2 plt.scatter(y_test[6], y_pred,  color='blue')
#       3 plt.xticks(())
#       4 plt.yticks(())
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...
